# %%
import scipy as sp
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pywt

# %% [markdown]
# USE ```pip install -r required_libs.txt``` ti install all necessary libraries!

# %% [markdown]
# For now using the signal from dataset, need to program and flash STM board and I have trouble doing so!
#
# Also need to re-thing if only one channel is usable. Might need 2 channels which would mean needing to buy new shield and vastly edit code.

# %%
file_path = 'D:\Python_files\VSC\Magisterka_EMG_VSCode\signal_2_data.csv'

# Read the CSV file
df = pd.read_csv(file_path)
print(df)
# Out:
#           Time (s)  EMG Signal
# 0         0.000000    0.008547
# 1         0.000333    0.010989
# 2         0.000667    0.018315
# 3         0.001000    0.003663
# 4         0.001333    0.008547
# ...            ...         ...
# 304635  101.545000    0.006105
# 304636  101.545333    0.001221
# 304637  101.545667    0.001221
# 304638  101.546000   -0.001221
# 304639  101.546333   -0.001221
#
# [304640 rows x 2 columns]
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\JASZCZUR\AppData\Local\Temp\ipykernel_5108\2456323625.py:1: SyntaxWarning: invalid escape sequence '\P'
#   file_path = 'D:\Python_files\Py_Charm\EMG_Magisterka\signal_2_data.csv'

# %%
fig, ax = plt.subplots()
ax.plot(df['Time (s)'], df['EMG Signal'], label='EMG Signal')  # Replace column names as needed
ax.set_title("EMG Signal")
ax.set_xlabel("Time (s)")
ax.set_ylabel("Amplitude")
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# I did some research on the filtration methods and will try a few to be later presented, for now I have:
#  - CWT (Continuos Wavelet Transform)
#  - Adaptive Filter -> good for eliminating PLI (Power Line Interference) and ECG artifacts
#  - EMD (Empirical Mode Decomposition)
